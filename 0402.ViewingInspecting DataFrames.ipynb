# %%
import pandas as pd
dataset = pd.read_csv(r'E:\cognilium Internship\Data Wrangling with python\04.Cleaning Structured Data\4.2\dataset.csv')
dataset
# Out:
#        id            Full Name Date of Birth                          email  \
# 0       1          Salim Pound     2/12/2018            spound0@spotify.com
# 1       2       Madelene Lutas     9/20/2018                 mlutas1@si.edu
# 2       3     Dolli Swanbourne    11/18/2018   dswanbourne2@istockphoto.com
# 3       4      Graeme Croisier     9/29/2018       gcroisier3@parallels.com
# 4       5       Jillana Physic     4/19/2018        jphysic4@yellowbook.com
# ..    ...                  ...           ...                            ...
# 995   996    Willie Gravestone     1/17/2018      wgravestonern@typepad.com
# 996   997     Samara McRitchie    12/10/2018    smcritchiero@wikispaces.com
# 997   998  Joceline Josefowicz    10/18/2018  jjosefowiczrp@statcounter.com
# 998   999        Andrei Lestor     1/16/2018          alestorrq@storify.com
# 999  1000       Nikkie Langtry    10/30/2018    nlangtryrr@sciencedaily.com
#
# ...

# %%
columns_name = list(dataset.columns)
columns_name
# Out:
# ['id',
#  'Full Name',
#  'Date of Birth',
#  'email',
#  'gender',
#  'Job',
#  'Company',
#  'Country',
#  'Phone',
#  'Income']

# %%
dataset.shape
# Out:
# (1000, 10)

# %%
dataset.dtypes
# Out:
# id                 int64
# Full Name         object
# Date of Birth     object
# email             object
# gender            object
# Job               object
# Company           object
# Country           object
# Phone             object
# Income           float64
# dtype: object

# %%
dataset['id'] = dataset['id'].astype('float')

dataset.dtypes
# Out:
# id               float64
# Full Name         object
# Date of Birth     object
# email             object
# gender            object
# Job               object
# Company           object
# Country           object
# Phone             object
# Income           float64
# dtype: object

# %%
rows = dataset[10:17]
rows
# Out:
#       id          Full Name Date of Birth                    email  gender  \
# 10  11.0     Charleen Auden     4/15/2018          caudena@nba.com  Female
# 11  12.0        Dame Povele     6/26/2018   dpoveleb@bloglovin.com    Male
# 12  13.0  Jesse Engelbrecht     4/16/2018  jengelbrechtc@google.ru  Female
# 13  14.0     Camey Barensen     8/21/2018     cbarensend@globo.com    Male
# 14  15.0   Alexandro Sember      4/8/2018         asembere@ibm.com    Male
# 15  16.0       Myrtia Towne     2/14/2018        mtownef@ifeng.com  Female
# 16  17.0     Shay Cakebread     9/27/2018     scakebreadg@webs.com    Male
#
#                             Job    Company  Country         Phone  \
# 10           Recruiting Manager  Topiczoom    Japan  197-554-9978
# 11                       Editor      Avamm      NaN  961-960-2015
# 12                Senior Editor    Oyonder   Guinea  611-343-2038
# 13  Computer Systems Analyst II   Innotype  Ukraine  824-632-8357
# ...
