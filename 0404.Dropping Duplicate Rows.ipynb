# %%
import pandas as pd
dataset = pd.read_csv(r'E:\cognilium Internship\Data Wrangling with python\04.Cleaning Structured Data\4.2\employees.csv')
dataset
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#                      Team
# 0               Marketing
# 1                     NaN
# 2                 Finance
# 3                 Finance
# ...

# %%
dataset.sort_values('First Name', inplace = True)
dataset
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#                 Team
# 101        Marketing
# 327        Marketing
# 440  Client Services
# 937  Client Services
# 137     Distribution
# ..               ...
# ...

# %%
df1 = dataset.copy()
df2 = dataset.copy()
df3 = dataset.copy()

# %%
df1.drop_duplicates(subset= 'First Name', keep= False, inplace= True)
df1 #Keep = False
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 688      Brian    Male    4/7/2007        10:47 PM   93901   17.821
# 190      Carol  Female   3/19/1996         3:39 AM   57783    9.129
# 887      David    Male   12/5/2009         8:48 AM   92242   15.407
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 495     Eugene    Male   5/24/1984        10:54 AM   81077    2.117
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 832      Keith    Male   2/12/2003         3:02 PM  120672   19.467
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
#
#                      Team
# 8             Engineering
# 688                 Legal
# 190               Finance
# 887                 Legal
# 5                   Legal
# 495                 Sales
# 33   Business Development
# 832                 Legal
# 291       Client Services

# %%
df2.drop_duplicates(subset= 'First Name', keep= 'first', inplace= True)
df2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# 300       Alan    Male   6/26/1988         3:54 AM  111786    3.592
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# ..         ...     ...         ...             ...     ...      ...
# 433      Wanda  Female   7/20/2008         1:44 PM   65362    7.132
# 177      Wayne    Male    4/7/2012         8:00 AM  102652   14.085
# 820    William    Male  11/18/1993        12:27 PM   54058    5.182
# 450     Willie    Male   8/22/2009         1:03 PM   55038   19.691
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
#
#                 Team
# 101        Marketing
# 137     Distribution
# 300      Engineering
# 372      Engineering
# 988  Human Resources
# ...

# %%
df3.drop_duplicates(subset= 'First Name', keep= 'last', inplace= True)
df3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN   1/22/1986         7:39 PM   63126   18.424
# 538       Adam    Male   10/8/2010         9:53 PM   45181    3.491
# 610       Alan    Male   2/17/2012        12:26 AM   41453   10.084
# 959     Albert    Male   9/19/1992         2:35 AM   45094    5.850
# 693      Alice  Female  10/16/1995         9:19 PM   92799    2.782
# ..         ...     ...         ...             ...     ...      ...
# 512      Wanda  Female    4/6/1993         3:11 AM   78883   19.695
# 637      Wayne    Male    9/2/2009         1:37 AM  126956   18.396
# 127    William    Male   9/29/2002         4:09 PM   66521    5.830
# 652     Willie    Male   12/5/2009         5:39 AM  141932    1.017
# 951        NaN  Female   9/14/2010         5:19 AM  143638    9.662
#
#                      Team
# 937       Client Services
# 538       Human Resources
# 610               Product
# 959  Business Development
# ...
