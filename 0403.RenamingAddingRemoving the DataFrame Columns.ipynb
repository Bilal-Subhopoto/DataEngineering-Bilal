# %%
import pandas as pd
dataset = pd.read_csv(r'E:\cognilium Internship\Data Wrangling with python\04.Cleaning Structured Data\4.2\dataset.csv')
dataset
# Out:
#        id            Full Name Date of Birth                          email  \
# 0       1          Salim Pound     2/12/2018            spound0@spotify.com
# 1       2       Madelene Lutas     9/20/2018                 mlutas1@si.edu
# 2       3     Dolli Swanbourne    11/18/2018   dswanbourne2@istockphoto.com
# 3       4      Graeme Croisier     9/29/2018       gcroisier3@parallels.com
# 4       5       Jillana Physic     4/19/2018        jphysic4@yellowbook.com
# ..    ...                  ...           ...                            ...
# 995   996    Willie Gravestone     1/17/2018      wgravestonern@typepad.com
# 996   997     Samara McRitchie    12/10/2018    smcritchiero@wikispaces.com
# 997   998  Joceline Josefowicz    10/18/2018  jjosefowiczrp@statcounter.com
# 998   999        Andrei Lestor     1/16/2018          alestorrq@storify.com
# 999  1000       Nikkie Langtry    10/30/2018    nlangtryrr@sciencedaily.com
#
# ...

# %%
columns_name = list(dataset.columns)
columns_name
# Out:
# ['id',
#  'Full Name',
#  'Date of Birth',
#  'email',
#  'gender',
#  'Job',
#  'Company',
#  'Country',
#  'Phone',
#  'Income']

# %%
dataset.rename(columns = {'Full Name':'Name','email':'Email Address'},inplace = True)
dataset
# Out:
#        id                 Name Date of Birth                  Email Address  \
# 0       1          Salim Pound     2/12/2018            spound0@spotify.com
# 1       2       Madelene Lutas     9/20/2018                 mlutas1@si.edu
# 2       3     Dolli Swanbourne    11/18/2018   dswanbourne2@istockphoto.com
# 3       4      Graeme Croisier     9/29/2018       gcroisier3@parallels.com
# 4       5       Jillana Physic     4/19/2018        jphysic4@yellowbook.com
# ..    ...                  ...           ...                            ...
# 995   996    Willie Gravestone     1/17/2018      wgravestonern@typepad.com
# 996   997     Samara McRitchie    12/10/2018    smcritchiero@wikispaces.com
# 997   998  Joceline Josefowicz    10/18/2018  jjosefowiczrp@statcounter.com
# 998   999        Andrei Lestor     1/16/2018          alestorrq@storify.com
# 999  1000       Nikkie Langtry    10/30/2018    nlangtryrr@sciencedaily.com
#
# ...

# %%
# dataset.drop(columns = ['Income'], inplace=True)
# this statement keeps showing error, 'Income not found'

# %%
names = dataset['Name']
list(names)
# Out:
# ['Salim Pound',
#  'Madelene Lutas',
#  'Dolli Swanbourne',
#  'Graeme Croisier',
#  'Jillana Physic',
#  'Anetta Yokelman',
#  'Modesta Batterson',
#  'Melina Boon',
#  'Nomi Warn',
#  'Leilah Ortner',
#  'Charleen Auden',
#  'Dame Povele',
#  'Jesse Engelbrecht',
#  'Camey Barensen',
#  'Alexandro Sember',
#  'Myrtia Towne',
#  'Shay Cakebread',
#  'Nerta McCutheon',
#  'Patin Mitchely',
#  'Malinda Heistermann',
#  'Luther Patullo',
#  'Melonie Blades',
#  'Lalo Robinet',
#  'Darleen McGinn',
#  'Gratiana Inglesfield',
#  'Belita Adan',
#  'Ramsay Pashe',
#  'Auberta Ivel',
#  'Mathew Strelitzer',
#  'Elliott Jeandillou',
#  'Gretel Haw',
#  'Tobi Spellard',
#  'Raphaela Wragge',
#  'Devinne Mogey',
#  'Silvanus Westhoff',
#  'Katusha Ouldcott',
#  'Melina Milton-White',
#  'Cheslie Tumpane',
#  'Lissa Ballefant',
#  'Gusta Guihen',
#  'Lanna Gowdie',
#  'Chadd Litchmore',
#  'Elias Khotler',
#  'Emmalynne Chimenti',
#  'Andrea Lovejoy',
#  'Durward Burlingham',
#  'Reid Haggar',
# ...

# %%
first_letter = list()
for i in names:
    first_letter.append(i[-2:-1]) #extracting last letter
first_letter
# Out:
# ['n',
#  'a',
#  'n',
#  'e',
#  'i',
#  'a',
#  'o',
#  'o',
#  'r',
#  'e',
#  'e',
#  'l',
#  'h',
#  'e',
#  'e',
#  'n',
#  'a',
#  'o',
#  'l',
#  'n',
#  'l',
#  'e',
#  'e',
#  'n',
#  'l',
#  'a',
#  'h',
#  'e',
#  'e',
#  'o',
#  'a',
#  'r',
#  'g',
#  'e',
#  'f',
#  't',
#  't',
#  'n',
#  'n',
#  'e',
#  'i',
#  'r',
#  'e',
#  't',
#  'o',
#  'a',
#  'a',
#  'e',
#  'a',
#  'r',
#  'l',
#  'n',
#  's',
#  'u',
#  'r',
#  'l',
#  'u',
#  'e',
#  'y',
#  'n',
#  't',
#  'i',
#  'f',
#  'c',
#  'a',
#  'i',
#  'k',
#  'm',
#  'o',
#  'o',
#  'a',
#  'w',
#  'r',
#  'e',
#  'd',
#  'r',
#  'l',
#  'e',
#  'g',
#  'h',
#  'e',
#  'a',
#  'o',
#  'l',
#  'a',
#  'l',
#  'o',
#  'o',
#  'r',
#  'i',
#  'n',
#  'e',
#  'e',
#  'e',
#  'i',
#  'o',
#  'h',
#  'c',
#  'a',
#  'e',
#  'n',
#  'l',
#  'e',
#  'c',
#  'l',
#  'k',
#  'c',
#  'i',
#  'd',
#  'l',
#  'c',
#  'h',
#  'e',
#  'l',
#  'e',
#  'n',
#  'n',
#  'o',
#  'o',
#  'n',
#  'n',
#  'e',
#  'i',
#  'e',
#  'n',
# ...

# %%
dataset['first letter']= first_letter #adding a column named 'first letter'
dataset
# Out:
#        id                 Name Date of Birth                  Email Address  \
# 0       1          Salim Pound     2/12/2018            spound0@spotify.com
# 1       2       Madelene Lutas     9/20/2018                 mlutas1@si.edu
# 2       3     Dolli Swanbourne    11/18/2018   dswanbourne2@istockphoto.com
# 3       4      Graeme Croisier     9/29/2018       gcroisier3@parallels.com
# 4       5       Jillana Physic     4/19/2018        jphysic4@yellowbook.com
# ..    ...                  ...           ...                            ...
# 995   996    Willie Gravestone     1/17/2018      wgravestonern@typepad.com
# 996   997     Samara McRitchie    12/10/2018    smcritchiero@wikispaces.com
# 997   998  Joceline Josefowicz    10/18/2018  jjosefowiczrp@statcounter.com
# 998   999        Andrei Lestor     1/16/2018          alestorrq@storify.com
# 999  1000       Nikkie Langtry    10/30/2018    nlangtryrr@sciencedaily.com
#
# ...
